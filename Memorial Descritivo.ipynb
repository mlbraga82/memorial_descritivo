# %%
import pandas as pd
from tabula import read_pdf
import numpy as np

# %%
df = read_pdf('document.pdf',output_format='dataframe',pages="all",stream=True)

# %%
data=pd.DataFrame(df[0])

# %%
colunas = ['Código',
 'Longitude','Latitude',
 'Altitude (m)',
 'Código',
 'Azimute',
 'Dist. (m)',
 'Confrontações',
 'NaN']

# %%
data.columns=colunas

# %%
data=data.drop(0,axis=0)

# %%
data=data.drop('NaN',axis=1)

# %%
mask=data['Latitude'].isnull()

# %%
for k,v in data[mask].iterrows():
    linha=data.loc[k,'Longitude']
    lon,lat=linha.split(' ')
    data.loc[k,'Longitude']=lon
    data.loc[k,'Latitude']=lat

# %%
data
# Out:
#            Código       Longitude       Latitude Altitude (m)       Código  \
# 1     PHDR-M-1198  -61°17'32,869"  -4°42'46,248"         40,0  PHDR-P-1199
# 2     PHDR-P-1199  -61°01'23,984"  -4°57'44,960"         40,0  PHDR-P-1200
# 3     PHDR-P-1200  -61°01'03,164"  -5°06'53,064"         40,0  PHDR-P-1201
# 4     PHDR-P-1201  -61°01'02,885"  -5°06'57,438"         40,0  PHDR-P-1202
# 5     PHDR-P-1202  -61°01'04,854"  -5°07'01,895"         40,0  PHDR-P-1203
# ...           ...             ...            ...          ...          ...
# 1305  PHDR-P-2502  -61°25'10,973"  -4°51'18,713"         40,0  PHDR-P-2503
# 1306  PHDR-P-2503  -61°19'15,123"  -4°45'59,290"         40,0  PHDR-P-2504
# 1307  PHDR-P-2504  -61°19'10,089"  -4°45'54,045"         40,0  PHDR-P-2505
# 1308  PHDR-P-2505  -61°18'33,639"  -4°45'06,988"         40,0  PHDR-P-2506
# 1309  PHDR-P-2506  -61°18'28,464"  -4°44'57,956"         40,0  PHDR-M-1198
#
#       Azimute Dist. (m)                Confrontações
# 1     132°46'  40661,56               Rodovia BR-319
# 2     177°49'  16848,67  Parque Estadual do Matupiri
# 3     176°20'    134,63                 Rio Matupiri
# 4     203°53'    149,72                 Rio Matupiri
# 5     192°17'    160,51                 Rio Matupiri
# ...       ...       ...                          ...
# 1305   48°10'  14714,19               Rodovia BR-319
# 1306   43°54'    223,67               Rodovia BR-319
# 1307   37°51'    1830,6               Rodovia BR-319
# 1308   29°53'    319,99               Rodovia BR-319
# 1309   22°57'   4393,56               Rodovia BR-319
#
# [1309 rows x 8 columns]

# %%
#list(data.columns)

# %%
memorial = 'Inicia-se a descrição deste perímetro no vértice '
for k,v in data.iterrows():
    if k==1:
        memorial=memorial+v[0]+', georreferenciado no Sistema Geodésico Brasileiro, DATUM - SIRGAS 2000,'+' de coordenadas (Longitude:'+v[1]+', Latitude:'+v[2]+')de altitude '+v[3]+' m; deste segue confrontando com a propriedade de '+v[7]+' com os seguintes azimutes e distâncias: '+v[5]+' e '+v[6]+' m até o vértice '+v[4]
    if k>1:
        memorial=memorial+', de coordenadas (Longitude:'+v[1]+', Latitude:'+v[2]+') de altitude '+v[3]+' m; deste segue confrontando com a propriedade de '+v[7]+' com os seguintes azimutes e distâncias:'+v[5]+' e '+v[6]+' m até o vértice '+v[4]

# %%
print(memorial)
# Out:
# Inicia-se a descrição deste perímetro no vértice PHDR-M-1198, georreferenciado no Sistema Geodésico Brasileiro, DATUM - SIRGAS 2000, de coordenadas (Longitude:-61°17'32,869", Latitude:-4°42'46,248")de altitude 40,0 m; deste segue confrontando com a propriedade de Rodovia BR-319 com os seguintes azimutes e distâncias: 132°46' e 40661,56 m até o vértice PHDR-P-1199, de coordenadas (Longitude:-61°01'23,984", Latitude:-4°57'44,960") de altitude 40,0 m; deste segue confrontando com a propriedade de Parque Estadual do Matupiri com os seguintes azimutes e distâncias:177°49' e 16848,67 m até o vértice PHDR-P-1200, de coordenadas (Longitude:-61°01'03,164", Latitude:-5°06'53,064") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:176°20' e 134,63 m até o vértice PHDR-P-1201, de coordenadas (Longitude:-61°01'02,885", Latitude:-5°06'57,438") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:203°53' e 149,72 m até o vértice PHDR-P-1202, de coordenadas (Longitude:-61°01'04,854", Latitude:-5°07'01,895") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:192°17' e 160,51 m até o vértice PHDR-P-1203, de coordenadas (Longitude:-61°01'05,963", Latitude:-5°07'07,000") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:226°04' e 83,05 m até o vértice PHDR-P-1204, de coordenadas (Longitude:-61°01'07,906", Latitude:-5°07'08,875") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:184°29' e 268,54 m até o vértice PHDR-P-1205, de coordenadas (Longitude:-61°01'08,588", Latitude:-5°07'17,591") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:178°39' e 267,71 m até o vértice PHDR-P-1206, de coordenadas (Longitude:-61°01'08,384", Latitude:-5°07'26,304") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:160°01' e 145,13 m até o vértice PHDR-P-1207, de coordenadas (Longitude:-61°01'06,774", Latitude:-5°07'30,744") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:165°47' e 180,18 m até o vértice PHDR-P-1208, de coordenadas (Longitude:-61°01'05,338", Latitude:-5°07'36,430") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:196°55' e 74,29 m até o vértice PHDR-P-1209, de coordenadas (Longitude:-61°01'06,040", Latitude:-5°07'38,744") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:214°12' e 125,76 m até o vértice PHDR-P-1210, de coordenadas (Longitude:-61°01'08,335", Latitude:-5°07'42,130") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:243°15' e 146,57 m até o vértice PHDR-P-1211, de coordenadas (Longitude:-61°01'12,585", Latitude:-5°07'44,277") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:259°47' e 120,65 m até o vértice PHDR-P-1212, de coordenadas (Longitude:-61°01'16,440", Latitude:-5°07'44,973") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:273°46' e 161,63 m até o vértice PHDR-P-1213, de coordenadas (Longitude:-61°01'21,677", Latitude:-5°07'44,627") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimutes e distâncias:265°12' e 163,67 m até o vértice PHDR-P-1214, de coordenadas (Longitude:-61°01'26,972", Latitude:-5°07'45,072") de altitude 40,0 m; deste segue confrontando com a propriedade de Rio Matupiri com os seguintes azimut ...
